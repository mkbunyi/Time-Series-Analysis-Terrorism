# %% [markdown]
# # Terrorism Trends and Determinants

# %%
# Data Management/Investigation
import wbdata
import pandas as pd
import numpy as np
#import country_converter as coco
import missingno as miss
import plotly.express as px
import seaborn as sns
import matplotlib.pyplot as plt
import datetime

# %% [markdown]
# # GTD Dataset

# %%
gtd = pd.read_excel("Data/globalterrorismdb_0919dist.xlsx")

# %%
gtd
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 0       197000000001   1970       7     2        NaN         0        NaT
# 1       197000000002   1970       0     0        NaN         0        NaT
# 2       197001000001   1970       1     0        NaN         0        NaT
# 3       197001000002   1970       1     0        NaN         0        NaT
# 4       197001000003   1970       1     0        NaN         0        NaT
# ...              ...    ...     ...   ...        ...       ...        ...
# 191459  201812310030   2018      12    31        NaN         0        NaT
# 191460  201812310031   2018      12    31        NaN         0        NaT
# 191461  201812310032   2018      12    31        NaN         0        NaT
# 191462  201812310033   2018      12    31        NaN         0        NaT
# 191463  201812310034   2018      12    31        NaN         0        NaT
#
#         country         country_txt  region  ...  \
# ...

# %%
gtd1993 = pd.read_excel("Data/gtd1993_0919dist.xlsx")
gtd1993
# Out:
#           eventid  iyear  imonth  iday approxdate  extended resolution  \
# 0    199301010001   1993       1     1        NaN         0        NaT
# 1    199301010002   1993       1     1        NaN         0        NaT
# 2    199301030001   1993       1     3        NaN         0        NaT
# 3    199301030002   1993       1     3        NaN         0        NaT
# 4    199301030003   1993       1     3        NaN         0        NaT
# ..            ...    ...     ...   ...        ...       ...        ...
# 743  199312280002   1993      12    28        NaN         0        NaT
# 744  199312300001   1993      12    30        NaN         0        NaT
# 745  199312300002   1993      12    30        NaN         0        NaT
# 746  199312300003   1993      12    30        NaN         0        NaT
# 747  199312300004   1993      12    30        NaN         0        NaT
#
#      country     country_txt  region  ...  \
# 0        603  United Kingdom       8  ...
# ...

# %%
# Check if the column names match
list(gtd.columns)==list(gtd1993.columns)
# Out:
# True

# %%
# Consolidate
gtdfinal = gtd.append(gtd1993)
gtdfinal
# Out:
#           eventid  iyear  imonth  iday approxdate  extended resolution  \
# 0    197000000001   1970       7     2        NaN         0        NaT
# 1    197000000002   1970       0     0        NaN         0        NaT
# 2    197001000001   1970       1     0        NaN         0        NaT
# 3    197001000002   1970       1     0        NaN         0        NaT
# 4    197001000003   1970       1     0        NaN         0        NaT
# ..            ...    ...     ...   ...        ...       ...        ...
# 743  199312280002   1993      12    28        NaN         0        NaT
# 744  199312300001   1993      12    30        NaN         0        NaT
# 745  199312300002   1993      12    30        NaN         0        NaT
# 746  199312300003   1993      12    30        NaN         0        NaT
# 747  199312300004   1993      12    30        NaN         0        NaT
#
#      country         country_txt  region  ...  \
# 0         58  Dominican Republic       2  ...
# ...

# %%
# export preprocessed file
gtdfinal.to_csv('Data/gtdfinal.csv')
